# %% [markdown]
# <a href="https://colab.research.google.com/github/claudia372440-lgtm/miprimerrepositorio/blob/main/Practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# UNIVERSIDAD TECMILENIO
# # FUNDAMENTOS Y APLICACIONES DE LA INTELIGENCIA ARTIFICIAL

# %%
# HOLA MUNDO
print("holamundo")
# Out:
# holamundo
