# %% [markdown]
# <a href="https://colab.research.google.com/github/claudia372440-lgtm/miprimerrepositorio/blob/MI_PRIMERA_RAMA/Practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# UNIVERSIDAD TECMILENIO
# # FUNDAMENTOS Y APLICACIONES DE LA INTELIGENCIA ARTIFICIAL

# %% [markdown]
# ##CLAUDIA ROCIO VELANDIA VELANDIA
# ###EJERCICIO DE PROGRAMACION
#
# ---

# %%
# HOLA MUNDO
print("holamundo")
# Out:
# holamundo

# %%
from re import A
#CALCULADFORA SIMPLE
a=int(input("ingrese el primer numero "))
b=int(input("ingrese el segundo numero "))
print("la suma es",a+b)
# Out:
# ingrese el primer numero 2
# ingrese el segundo numero 4
# la suma es 6
